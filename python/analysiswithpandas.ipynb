# %% [markdown]
# # Pandas Dataframe ???

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/PyaePhyoAye/pandas1.csv')

# %%
pd.read_json('https://api.covidtracking.com/v1/us/daily.json')
# Out:
#          date  states    positive    negative  pending  hospitalizedCurrently  \
# 0    20210307      56  28756489.0  74582825.0  11808.0                40199.0
# 1    20210306      56  28714654.0  74450990.0  11783.0                41401.0
# 2    20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3    20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4    20210303      56  28520365.0  73857281.0  11778.0                45462.0
# ..        ...     ...         ...         ...      ...                    ...
# 415  20200117       1         0.0         NaN      NaN                    NaN
# 416  20200116       1         0.0         NaN      NaN                    NaN
# 417  20200115       1         0.0         NaN      NaN                    NaN
# 418  20200114       1         0.0         NaN      NaN                    NaN
# 419  20200113       1         NaN         NaN      NaN                    NaN
#
# ...

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is D215-09A5
#
#  Directory of C:\Users\PyaePhyoAye
#
# 08/03/2024  04:45 PM    <DIR>          .
# 02/05/2024  03:07 PM    <DIR>          ..
# 07/13/2024  04:18 PM    <DIR>          .anaconda
# 06/08/2024  05:28 PM                12 .bash_history
# 08/03/2024  04:46 PM    <DIR>          .conda
# 07/13/2024  04:19 PM                25 .condarc
# 07/13/2024  04:18 PM    <DIR>          .continuum
# 06/08/2024  07:11 PM               161 .gitconfig
# 08/03/2024  04:12 PM    <DIR>          .ipynb_checkpoints
# 07/13/2024  04:47 PM    <DIR>          .ipython
# 07/14/2024  04:04 PM    <DIR>          .jupyter
# 06/22/2024  06:13 PM                20 .lesshst
# 06/08/2024  09:57 PM    <DIR>          .ssh
# 06/08/2024  07:12 PM               689 .viminfo
# 07/13/2024  04:18 PM    <DIR>          anaconda3
# 08/03/2024  04:45 PM            22,680 analysiswithpandas.ipynb
# 02/05/2024  03:07 PM    <DIR>          Contacts
# ...

# %%
df1 =df.copy()

# %%
df1
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df1['Gender'].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df1['EducationLevel'].value_counts()
# Out:
# EducationLevel
# Bachelors              9119
# Partial College        8091
# Graduate Degree        5418
# High School            5006
# Partial High School    2365
# Name: count, dtype: int64

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# M    15009
# F    14790
# Name: count, dtype: int64

# %%
df1['Occupation'].value_counts()
# Out:
# Occupation
# Professional      9482
# Skilled Manual    7234
# Management        5319
# Clerical          4602
# Manual            3362
# Name: count, dtype: int64

# %%
df1['Occupation']=='Professional' #boolean
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 29994     True
# 29995     True
# 29996     True
# 29997     True
# 29998     True
# Name: Occupation, Length: 29999, dtype: bool

# %%
professional = df1[df1['Occupation']=='Professional']

# %%
professional
# Out:
#          OrderDate                  Name      BirthDate Gender  \
# 1      1/1/15 0:00   MR. KYLE WASHINGTON   4/11/55 0:00      M
# 6      1/2/15 0:00    MRS. GRACE JENKINS   3/16/62 0:00      F
# 13     1/3/15 0:00  MRS. ALEXANDRA ADAMS  10/16/58 0:00      F
# 14     1/3/15 0:00      MRS. JENNA LOPEZ   4/23/68 0:00      F
# 17     1/4/15 0:00    MR. RICHARD PARKER  11/15/58 0:00      M
# ...            ...                   ...            ...    ...
# 29994  2/4/17 0:00       MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00       MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00       MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00       MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00      MR. DALTON PEREZ    4/4/57 0:00      M
#
#                           EmailAddress AnnualIncome  Sum of TotalChildren  \
# 1            kyle8@adventure-works.com     $80,000                      3
# ...

# %%
maleprofessional = df1[(df1['Occupation']=='Professional') & (df1['Gender']=='M')]

# %%
maleprofessional
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 17     1/4/15 0:00   MR. RICHARD PARKER  11/15/58 0:00      M
# 23     1/5/15 0:00     MR. MIGUEL GREEN   7/22/60 0:00      M
# 24     1/6/15 0:00     MR. LUIS COLLINS   9/21/49 0:00      M
# 25     1/6/15 0:00     MR. RICHARD WARD  11/28/63 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                         EmailAddress AnnualIncome  Sum of TotalChildren  \
# 1          kyle8@adventure-works.com     $80,000                      3
# 17     richard36@adventure-works.com     $80,000                      5
# ...

# %%
marriedmaleprofessional = df1[(df1['Occupation']=='Professional') & (df1['Gender']=='M') & (df1['Sum of totalChildren'] > 0)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sum of totalChildren'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
#Check Null

# %%
df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df1.info()
#
# NameError: name 'df1' is not defined

# %%
df1.isna().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df1[df1['Gender'].isna()]
# Out:
#           OrderDate                 Name     BirthDate Gender  \
# 153    1/27/15 0:00          RICKY GOMEZ  7/21/59 0:00    NaN
# 235     2/9/15 0:00      HAROLD MCDONALD  5/23/60 0:00    NaN
# 409    3/10/15 0:00         ANGELA PERRY  6/27/73 0:00    NaN
# 555     4/3/15 0:00          DENNIS WARE  10/4/50 0:00    NaN
# 639    4/16/15 0:00   VANESSA WASHINGTON  4/14/73 0:00    NaN
# ...             ...                  ...           ...    ...
# 29427  1/30/17 0:00        MISTY CHANDER  4/17/57 0:00    NaN
# 29850   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29851   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29852   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
# 29853   2/3/17 0:00          GAIL BUTLER  2/24/58 0:00    NaN
#
#                         EmailAddress AnnualIncome  Sum of TotalChildren  \
# 153       ricky1@adventure-works.com    $100,000                      5
# 235     harold11@adventure-works.com     $20,000                      1
# ...

# %%
df2 = df1.copy()

# %%
df2.isnull().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df2.dropna()
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  Sum of TotalChildren  \
# 0          john48@adventure-works.com     $80,000                      1
# ...

# %%
df2.isnull().sum()
# Out:
# OrderDate                   0
# Name                        0
# BirthDate                   0
# Gender                    200
# EmailAddress                0
# AnnualIncome                0
# Sum of TotalChildren        0
# EducationLevel              0
# Occupation                  0
# HomeOwner                   0
# ProductSKU                  0
# ProductName                 0
# ProductDescription          0
# ProductColor            13632
# ProductSize                 0
# ProductStyle                0
# Sum of ProductPrice         0
# Sum of OrderQuantity        0
# SubcategoryName             0
# Region                      0
# Country                     0
# Continent                   0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29799 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df1['Gender'].fillna('Not Define',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          16367 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df1['Gender'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29994    False
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# Name: Gender, Length: 29999, dtype: bool

# %%
df1['ProductColor'].fillna('No Color',inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   Sum of TotalChildren  29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# OrderDate               0
# Name                    0
# BirthDate               0
# Gender                  0
# EmailAddress            0
# AnnualIncome            0
# Sum of TotalChildren    0
# EducationLevel          0
# Occupation              0
# HomeOwner               0
# ProductSKU              0
# ProductName             0
# ProductDescription      0
# ProductColor            0
# ProductSize             0
# ProductStyle            0
# Sum of ProductPrice     0
# Sum of OrderQuantity    0
# SubcategoryName         0
# Region                  0
# Country                 0
# Continent               0
# dtype: int64

# %%
df5 = df1.copy()

# %%
df5.columns
# Out:
# Index(['OrderDate', 'Name', 'BirthDate', 'Gender', 'EmailAddress',
#        'AnnualIncome', 'Sum of TotalChildren', 'EducationLevel', 'Occupation',
#        'HomeOwner', 'ProductSKU', 'ProductName', 'ProductDescription',
#        'ProductColor', 'ProductSize', 'ProductStyle', 'Sum of ProductPrice',
#        'Sum of OrderQuantity', 'SubcategoryName', 'Region', 'Country',
#        'Continent'],
#       dtype='object')

# %%
df5.rename(columns = {'Sum of TotalChildren':'TotalChildren'},inplace=True)

# %%
df5.columns
# Out:
# Index(['OrderDate', 'Name', 'BirthDate', 'Gender', 'EmailAddress',
#        'AnnualIncome', 'TotalChildren', 'EducationLevel', 'Occupation',
#        'HomeOwner', 'ProductSKU', 'ProductName', 'ProductDescription',
#        'ProductColor', 'ProductSize', 'ProductStyle', 'Sum of ProductPrice',
#        'Sum of OrderQuantity', 'SubcategoryName', 'Region', 'Country',
#        'Continent'],
#       dtype='object')

# %%
df5.drop(columns={'HomeOwener'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df5.drop(columns={'HomeOwener'},inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
df5['Sales'] = df5['ProductSize'] * df5['Sum of OrderQuantity']

# %%
df5.columns
# Out:
# Index(['OrderDate', 'Name', 'BirthDate', 'Gender', 'EmailAddress',
#        'AnnualIncome', 'TotalChildren', 'EducationLevel', 'Occupation',
#        'HomeOwner', 'ProductSKU', 'ProductName', 'ProductDescription',
#        'ProductColor', 'ProductSize', 'ProductStyle', 'Sum of ProductPrice',
#        'Sum of OrderQuantity', 'SubcategoryName', 'Region', 'Country',
#        'Continent', 'Sales'],
#       dtype='object')

# %%
df5
# Out:
#          OrderDate                 Name      BirthDate Gender  \
# 0      1/1/15 0:00      MR. JOHN THOMAS  11/11/58 0:00      M
# 1      1/1/15 0:00  MR. KYLE WASHINGTON   4/11/55 0:00      M
# 2      1/1/15 0:00        MR. ROSS SANZ   4/21/74 0:00      M
# 3      1/1/15 0:00       MR. SETH LEWIS   9/25/80 0:00      M
# 4      1/2/15 0:00   MR. ALEJANDRO CHEN   1/11/65 0:00      M
# ...            ...                  ...            ...    ...
# 29994  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29995  2/4/17 0:00      MR. CLAYTON JAI    7/8/76 0:00      M
# 29996  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29997  2/4/17 0:00      MR. CONNOR KING   3/12/60 0:00      M
# 29998  2/4/17 0:00     MR. DALTON PEREZ    4/4/57 0:00      M
#
#                          EmailAddress AnnualIncome  TotalChildren  \
# 0          john48@adventure-works.com     $80,000               1
# 1           kyle8@adventure-works.com     $80,000               3
# ...

# %%
df5.groupby(by='OrderDate').agg('sum')
# Out:
#                                                            Name  \
# OrderDate
# 1/1/15 0:00   MR. JOHN THOMASMR. KYLE WASHINGTONMR. ROSS SAN...
# 1/1/16 0:00   MR. ERIC CHENMR. MARTIN GARCIAMRS. KATHERINE W...
# 1/1/17 0:00   MR. AARON GRIFFINMR. AARON GRIFFINMR. AARON GR...
# 1/10/15 0:00  MR. IAN EDWARDSMRS. DAWN NATHMRS. KATRINA ANAN...
# 1/10/16 0:00  MR. ALFREDO MUNOZMR. BILLY BLANCOMR. DUSTIN PA...
# ...                                                         ...
# 9/7/16 0:00    TERESA DOMINGUEZ TERESA DOMINGUEZ TERESA DOMI...
# 9/8/15 0:00   MR. ANTHONY CLARKMR. DUSTIN JAIMR. GILBERT HUA...
# 9/8/16 0:00   MR. ADRIAN RAMIREZMR. ADRIAN RAMIREZMR. ADRIAN...
# 9/9/15 0:00   MR. ALEXANDER MILLERMR. BRANDON THOMPSONMR. WI...
# 9/9/16 0:00   MR. ADAM PEREZMR. ADAM PEREZMR. ANDY GUTIERREZ...
#
#                                                       BirthDate  \
# OrderDate
# 1/1/15 0:00   11/11/58 0:004/11/55 0:004/21/74 0:009/25/80 0:00
# ...

# %%
df5.columns
# Out:
# Index(['OrderDate', 'Name', 'BirthDate', 'Gender', 'EmailAddress',
#        'AnnualIncome', 'TotalChildren', 'EducationLevel', 'Occupation',
#        'HomeOwner', 'ProductSKU', 'ProductName', 'ProductDescription',
#        'ProductColor', 'ProductSize', 'ProductStyle', 'Sum of ProductPrice',
#        'Sum of OrderQuantity', 'SubcategoryName', 'Region', 'Country',
#        'Continent', 'Sales'],
#       dtype='object')

# %%
df5[['OrderDate','Sum of OrderQuantity']].groupby(by='OrderDate').agg('sum')
# Out:
#               Sum of OrderQuantity
# OrderDate
# 1/1/15 0:00                      4
# 1/1/16 0:00                      8
# 1/1/17 0:00                    108
# 1/10/15 0:00                     4
# 1/10/16 0:00                    10
# ...                            ...
# 9/7/16 0:00                    218
# 9/8/15 0:00                      9
# 9/8/16 0:00                    215
# 9/9/15 0:00                      9
# 9/9/16 0:00                    237
#
# [765 rows x 1 columns]

# %%
df6 = df5[['EducationLevel','Occupation','Country','Sum of OrderQuantity']]

# %%
df6[['EducationLevel','Sum of OrderQuantity']].groupby(by='OrderDate').agg('sum')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df6[['EducationLevel','Sum of OrderQuantity']].groupby(by='OrderDate').agg('sum')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  object
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   TotalChildren         29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
#  14  ProductSize           29999 non-null  object
# ...

# %%
df5['OrderDate']
# Out:
# 0        1/1/15 0:00
# 1        1/1/15 0:00
# 2        1/1/15 0:00
# 3        1/1/15 0:00
# 4        1/2/15 0:00
#             ...
# 29994    2/4/17 0:00
# 29995    2/4/17 0:00
# 29996    2/4/17 0:00
# 29997    2/4/17 0:00
# 29998    2/4/17 0:00
# Name: OrderDate, Length: 29999, dtype: object

# %%
#Data Type Change

# %%
pd.to_datetime(df5['OrderDate'])
# Out:
# C:\Users\PyaePhyoAye\AppData\Local\Temp\ipykernel_17092\1842798622.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df5['OrderDate'])
# 0       2015-01-01
# 1       2015-01-01
# 2       2015-01-01
# 3       2015-01-01
# 4       2015-01-02
#            ...
# 29994   2017-02-04
# 29995   2017-02-04
# 29996   2017-02-04
# 29997   2017-02-04
# 29998   2017-02-04
# Name: OrderDate, Length: 29999, dtype: datetime64[ns]

# %%
df5['OrderDate']=pd.to_datetime(df5['OrderDate'])
# Out:
# C:\Users\PyaePhyoAye\AppData\Local\Temp\ipykernel_17092\2742432392.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df5['OrderDate']=pd.to_datetime(df5['OrderDate'])

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   TotalChildren         29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df5['OrderDate'].dt.year
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 29994    2017
# 29995    2017
# 29996    2017
# 29997    2017
# 29998    2017
# Name: OrderDate, Length: 29999, dtype: int32

# %%
df5['OrderDate'].dt.month
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 29994    2
# 29995    2
# 29996    2
# 29997    2
# 29998    2
# Name: OrderDate, Length: 29999, dtype: int32

# %%
# Year Group By

# %%
df5['Year'] = df5['OrderDate'].dt.year

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   TotalChildren         29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df5[['Year','Sum of OrderQuantity']].groupby(by='Year').agg('sum')
# Out:
#       Sum of OrderQuantity
# Year
# 2015                  2630
# 2016                 36230
# 2017                  5371

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   TotalChildren         29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
df5['Month'] = df5['OrderDate'].dt.month

# %%
# MOnth Of group by order qty

# %%
df5[['Month','Sum of OrderQuantity']].groupby(by='Month').agg('sum')
# Out:
#        Sum of OrderQuantity
# Month
# 1                      5276
# 2                       953
# 3                       464
# 4                       494
# 5                       535
# 6                       524
# 7                      2201
# 8                      6236
# 9                      6166
# 10                     6610
# 11                     6523
# 12                     8249

# %%
df5['Name of Month'] = df5['OrderDate'].dt.month_name()

# %%
df5[['Name of Month','Sum of OrderQuantity']].groupby(by='Name of Month').agg('sum')
# Out:
#                Sum of OrderQuantity
# Name of Month
# April                           494
# August                         6236
# December                       8249
# February                        953
# January                        5276
# July                           2201
# June                            524
# March                           464
# May                             535
# November                       6523
# October                        6610
# September                      6166

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderDate             29999 non-null  datetime64[ns]
#  1   Name                  29999 non-null  object
#  2   BirthDate             29999 non-null  object
#  3   Gender                29999 non-null  object
#  4   EmailAddress          29999 non-null  object
#  5   AnnualIncome          29999 non-null  object
#  6   TotalChildren         29999 non-null  int64
#  7   EducationLevel        29999 non-null  object
#  8   Occupation            29999 non-null  object
#  9   HomeOwner             29999 non-null  object
#  10  ProductSKU            29999 non-null  object
#  11  ProductName           29999 non-null  object
#  12  ProductDescription    29999 non-null  object
#  13  ProductColor          29999 non-null  object
# ...

# %%
# pivot

# %%
df5.pivot_table(index='EducationLevel',columns='Gender',values='Sum of OrderQuantity',aggfunc='sum')
# Out:
# Gender                  F     M  Not Define
# EducationLevel
# Bachelors            6332  6725          74
# Graduate Degree      3912  3999          47
# High School          3655  3818          47
# Partial College      5968  5890          96
# Partial High School  1809  1820          39

# %%
df5.pivot_table(index='Occupation',columns='Gender',values='Sum of OrderQuantity',aggfunc='sum')
# Out:
# Gender             F     M  Not Define
# Occupation
# Clerical        3183  3379          71
# Management      3755  4039          43
# Manual          2449  2593          45
# Professional    6939  6915          79
# Skilled Manual  5350  5326          65

# %%
df5.pivot_table(index='Occupation',columns='EducationLevel',values='Sum of OrderQuantity',aggfunc='sum')
# Out:
# EducationLevel  Bachelors  Graduate Degree  High School  Partial College  \
# Occupation
# Clerical             1504             1247          132             2761
# Management           3963             2678          912              235
# Manual                200              155         1688             1682
# Professional         4949             2069         2332             4198
# Skilled Manual       2515             1809         2456             3078
#
# EducationLevel  Partial High School
# Occupation
# Clerical                        989
# Management                       49
# Manual                         1362
# Professional                    385
# Skilled Manual                  883

# %% [markdown]
# # join the tables
